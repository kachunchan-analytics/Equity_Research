# %% [markdown]
# # Extracting 10K fact values
# First, use another script to make sure the TICKER.json exist <br>
# We can then copy the trimmed Json to chatgpt, and then ask for drafting graph and equity report

# %%
import requests
import json
from sec_cik_mapper import StockMapper
global symbol
from IPython.display import HTML, display

def obtain_trimmed_fact(data, fact,years):
    print(data['facts']['us-gaap'][f'{fact}']['label'])
    print(data['facts']['us-gaap'][f'{fact}']['description'])
    available_forms = [i['form'] for i in (data['facts']['us-gaap'][f'{fact}']['units']['USD'])]
    data = data['facts']['us-gaap'][f'{fact}']['units']['USD']
    
    print(f"The available forms are: {set(available_forms)}")
    form_selected = input (r"Filter to display which form?")
    new_list = []
    if form_selected:
        for i in data:
            if i['form'] == form_selected:
                new_list.append(i)
        return new_list[-years:]
    elif form_selected == "":
        return data

def obtain_trimmed_fact(data, fact, years):
    print(data['facts']['us-gaap'][f'{fact}']['label'])
    print(data['facts']['us-gaap'][f'{fact}']['description'])
    available_forms = [i['form'] for i in (data['facts']['us-gaap'][f'{fact}']['units']['USD'])]
    data = data['facts']['us-gaap'][f'{fact}']['units']['USD']
    
    print(f"The available forms are: {set(available_forms)}")
    form_selected = input (r"Filter to display which form? ")
    new_list = []
    if form_selected:
        for i in data:
            if i['form'] == form_selected:
                new_list.append(i)
        result = ','.join(str(i) for i in new_list[-years:])
    elif form_selected == "":
        result = ','.join(str(i) for i in data)
    #print(result)
    return result

# %% [markdown]
# ## Inputting ticker and load Json

# %%
ticker = "agba"
file_path = f"./SEC_company_facts/{ticker.upper()}.json"
with open(file_path, 'r') as f:
    data = json.load(f)
    print(f'{ticker.upper()}.json loaded')
# Out:
# AGBA.json loaded

# %% [markdown]
# ## Generating ALL fact labels and Copy Buttons

# %%
fact_list = [i for i in data['facts']['us-gaap'].keys()]



# Create a HTML table with copy buttons
html_table = "<table>"
for item in fact_list:
    html_table += f"<tr><td>{item}</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = \"#aaa\"; this.style.color = \"#fff\";'>Copy</button></td></tr>"
html_table += "</table>"

# Define the copyToClipboard function
copy_js = """
<script>
function copyToClipboard(text) {
    const textarea = document.createElement('textarea');
    textarea.value = text;
    document.body.appendChild(textarea);
    textarea.select();
    document.execCommand('copy');
    document.body.removeChild(textarea);
}
</script>
"""

# Display the HTML table and JavaScript code
display(HTML(html_table + copy_js))
# Out:
# <table><tr><td>AccruedLiabilitiesCurrent</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>AccumulatedOtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>AccumulatedOtherComprehensiveIncomeLossNetOfTax</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>AccumulatedOtherComprehensiveIncomeLossOtherThanTemporaryImpairmentNotCreditLossNetOfTaxAvailableforsaleDebtSecurities</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>AdditionalPaidInCapital</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>Assets</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>AssetsCurrent</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>AssetsDesignatedToClosedBlockEquitySecuritiesAvailableForSaleAtFairValue</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>AssetsHeldInTrust</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>AssetsHeldInTrustCurrent</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>AssetsHeldInTrustNoncurrent</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>BusinessAcquisitionEquityInterestsIssuedOrIssuableNumberOfSharesIssued</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedNet</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>CashAndCashEquivalentsAtCarryingValue</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>CashAndCashEquivalentsPeriodIncreaseDecrease</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseExcludingExchangeRateEffect</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>ChangeInUnrealizedGainLossOnFairValueHedgingInstruments1</td><td><button onclick='copyToClipboard(this.parentNode.parentNode.cells[0].textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy</button></td></tr><tr><td>ClassOfWarrantOrRightOu ...

# %% [markdown]
# ## Selecting Fact to give trimmed Json
# Take the above fact and paste

# %%
fact = input("Please paste the fact selected: ")

result = obtain_trimmed_fact(data, fact, 10)

# Define the copyToClipboard function
copy_js = """
<script>
function copyToClipboard(text) {
    const elem = document.createElement('p');
    elem.textContent = text;
    elem.style.whiteSpace = 'pre'; // to preserve whitespace
    navigator.clipboard.writeText(elem.textContent);
}
</script>
"""

html_result = HTML(f"<p id='result'>{fact}: {result}</p>")
display(HTML(copy_js))
display(html_result)
display(HTML(f"<button onclick='copyToClipboard(document.querySelector(\"#result\").textContent); this.style.background = \"#aaa\"; this.style.color = \"#fff\";'>Copy to Clipboard</button>"))
# Out:
# Please paste the fact selected:  Assets
# Assets
# Sum of the carrying amounts as of the balance sheet date of all assets that are recognized. Assets are probable future economic benefits obtained or controlled by an entity as a result of past transactions or events.
# The available forms are: {'10-Q/A', '10-K', '10-Q', '10-K/A'}
# Filter to display which form?  10-K
# <script>
# function copyToClipboard(text) {
#     const elem = document.createElement('p');
#     elem.textContent = text;
#     elem.style.whiteSpace = 'pre'; // to preserve whitespace
#     navigator.clipboard.writeText(elem.textContent);
# }
# </script>
# <p id='result'>Assets: {'end': '2018-12-31', 'val': 72500, 'accn': '0001213900-20-008207', 'fy': 2019, 'fp': 'FY', 'form': '10-K', 'filed': '2020-03-31', 'frame': 'CY2018Q4I'}{'end': '2019-12-31', 'val': 47559327, 'accn': '0001213900-20-008207', 'fy': 2019, 'fp': 'FY', 'form': '10-K', 'filed': '2020-03-31'}{'end': '2019-12-31', 'val': 47559327, 'accn': '0001213900-21-018015', 'fy': 2020, 'fp': 'FY', 'form': '10-K', 'filed': '2021-03-26'}{'end': '2020-12-31', 'val': 48954047, 'accn': '0001213900-21-018015', 'fy': 2020, 'fp': 'FY', 'form': '10-K', 'filed': '2021-03-26'}{'end': '2020-12-31', 'val': 48954047, 'accn': '0001213900-22-012228', 'fy': 2021, 'fp': 'FY', 'form': '10-K', 'filed': '2022-03-14', 'frame': 'CY2020Q4I'}{'end': '2021-12-31', 'val': 40606332, 'accn': '0001213900-22-012228', 'fy': 2021, 'fp': 'FY', 'form': '10-K', 'filed': '2022-03-14'}{'end': '2021-12-31', 'val': 122510300, 'accn': '0001213900-23-026399', 'fy': 2022, 'fp': 'FY', 'form': '10-K', 'filed': '2023-04-03', 'frame': 'CY2021Q4I'}{'end': '2022-12-31', 'val': 101221333, 'accn': '0001213900-23-026399', 'fy': 2022, 'fp': 'FY', 'form': '10-K', 'filed': '2023-04-03'}{'end': '2022-12-31', 'val': 101221333, 'accn': '0001213900-24-027225', 'fy': 2023, 'fp': 'FY', 'form': '10-K', 'filed': '2024-03-28', 'frame': 'CY2022Q4I'}{'end': '2023-12-31', 'val': 66588967, 'accn': '0001213900-24-027225', 'fy': 2023, 'fp': 'FY', 'form': '10-K', 'filed': '2024-03-28'}</p>
# <button onclick='copyToClipboard(document.querySelector("#result").textContent); this.style.background = "#aaa"; this.style.color = "#fff";'>Copy to Clipboard</button>

# %% [markdown]
# # Graph plotting area

# %%
import matplotlib.pyplot as plt

# Extract the values from the dataset
values = [72500, 955351, 955351, 704138, 704138, 164863, 83779515, 55756165, 55756165, 25618972]

# Extract the corresponding years from the dataset
years = [2018, 2019, 2019, 2020, 2020, 2021, 2021, 2022, 2022, 2023]

# Create the figure and axis
fig, ax = plt.subplots()

# Create the bar chart
ax.bar(years, values)

# Set the title and labels
ax.set_title('Asset Values Over Time')
ax.set_xlabel('Year')
ax.set_ylabel('Asset Value')

# Show the plot
plt.show()
